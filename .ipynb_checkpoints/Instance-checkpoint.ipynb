# %%
from Populations import *
from PhagePopulation import *
import matplotlib.pyplot as plt
import numpy as np
import itertools as itTools
import math
import time

# %%
class Instance():
    def __init__(self, initialHostPopulationValues, initialPhagePopulationValues, carryingCap, fitnessParameters, lysisQuantities, hostMutMatrix, infectionMatrix, numIters):
        self.hostPopulations = []
        self.phagePopulations = []
        self.carryingCapacity = carryingCap
        self.numIterations = numIters
        self.maximumTimeResolution = 0.01
        
        self.initializePopulations(initialHostPopulationValues, initialPhagePopulationValues, fitnessParameters, lysisQuantities)

        self.timeValues = np.zeros(numIters + 1)
        
        self.hostPopulationValues = np.zeros((len(self.hostPopulations), numIters + 1))
        self.hostPopulationValues[:, 0] = [self.hostPopulations[k].populationLevel for k in range(len(self.hostPopulations))]
        
        self.phagePopulationValues = np.zeros((len(self.phagePopulations), numIters + 1))
        self.phagePopulationValues[:, 0] = [self.phagePopulations[k].populationLevel for k in range(len(self.phagePopulations))]

        self.hostMutationMatrix = hostMutMatrix
        self.phageHostInfectionMatrix = infectionMatrix
        self.completedRun = False

    def initializePopulations(self, initialHostPopVals, initialPhagePopVals, fitnessParams, lysisQuantities):
        for j in range(len(fitnessParams)):
            self.hostPopulations.append(hostPopulation(j, initialHostPopVals[j], fitnessParams[j]))

        hostPopVals = [pop.populationLevel for pop in self.hostPopulations]
        for pop in self.hostPopulations:
            pop.computeGrowthRate(hostPopVals, self.carryingCapacity)
            pop.regenerateTimer()
            
        for j in range(len(initialPhagePopVals)):
            self.phagePopulations.append(phagePopulation(j, initialPhagePopVals[j], lysisQuantities[0], lysisQuantities[1]))


    def runAlgorithm(self):
        for k in range(self.numIterations):
            #Step 1
            (update, minTimer, virocell, minPopIdx) = self.findMinPopTimer()
            
            #Step 2
            self.timeValues[k + 1] = self.timeValues[k] + minTimer
            
            #Step 3

            if update:
                if not virocell:
                    self.updateHostPopulation(minPopIdx)
                else:
                    self.updatePhagePopulation(minPopIdx)
            
            self.hostPopulationValues[:, k + 1] = [self.hostPopulations[k].populationLevel for k in range(len(self.hostPopulations))]

            #ChatGPT is nice: really, really try debugging yourself first though!
            self.phagePopulationValues[:, k + 1] = [self.phagePopulations[k].populationLevel for k in range(len(self.phagePopulations))]
    
            #Step 4
            self.recomputeGrowthRates()
    
            #Step 5
            self.updateHostTimers(minTimer)
            self.updatePhageTimers(minTimer)
    
            #Step 6
            self.regeneratePopTimers()

        self.completedRun = True
    
    def findMinPopTimer(self):
        hostPopTimers = [pop.getTimer() for pop in self.hostPopulations]
        phagePopTimers = [pop.getTimer() for pop in self.phagePopulations]
        minHostTimer = min(hostPopTimers)
        minPhageTimer = min(phagePopTimers)
        
        minHostPopTimerIdx = hostPopTimers.index(minHostTimer)
        minPhagePopTimerIdx = phagePopTimers.index(minPhageTimer)

        virocell = minHostTimer > minPhageTimer
        if not virocell:
            minTimer = minHostTimer
            minPopTimerIdx = minHostPopTimerIdx
        else:
            minTimer = minPhageTimer
            minPopTimerIdx = minPhagePopTimerIdx

        if minTimer > self.maximumTimeResolution:
            toUpdateOrNotToUpdate = False
            minTimer = self.maximumTimeResolution
        else:
            toUpdateOrNotToUpdate = True
            
        return (toUpdateOrNotToUpdate, minTimer, virocell, minPopTimerIdx)

    def updateHostPopulation(self, minPopIdx):
        #Get the growth rate's sign to see growth or death
        growth_rate = self.hostPopulations[minPopIdx].growthRate
        
        if growth_rate > 0:
            localMutationProbabilities = self.hostMutationMatrix[minPopIdx, :]
            possibilities = [n for n in range(len(self.hostPopulations))]
            #random.choice(what you're choosing from, how many you're choosing, are you replacing, weights)
            spawnChoiceIdx = np.random.choice(possibilities, None, True, localMutationProbabilities)
            self.hostPopulations[spawnChoiceIdx].changePopulation(1)
        elif growth_rate < 0:
            self.hostPopulations[minPopIdx].changePopulation(-1)
        else:
            self.hostPopulations[minPopIdx].changePopulation(0)

    def everyHostIsNotInfectedProb(self, infectionProb, numHosts):
        return (1 - infectionProb)**numHosts

    def infectionDistribution(self, hostPopulations, viralType):
        totalPops = np.sum(hostPopulations)
    
        if totalPops == 0:
            return [0 for k in range(len(hostPopulations))]
        
        normalizedHostPops = hostPopulations / totalPops
        nonzeroPops = [numPops for numPops in normalizedHostPops if numPops != 0]
    
        #This tuple contains what population types are not at zero
        nonzeroPopulationIndices = np.nonzero(hostPopulations)
        print("\nExtant Host Types: {}".format(nonzeroPopulationIndices[0]))
        
        
        print("\nPop Fracs = {}".format(nonzeroPops))
        m = len(nonzeroPops)
        nonzeroHostTypes = nonzeroPopulationIndices[0]
        
        #These probabilities are just designed as tests to give each coin a different probability without any of them being 1 or 0
        infectionProbabilities = self.phageHostInfectionMatrix[viralType]
        #print("\nHeads Probabilities: {}".format(infectionProbabilities))
        amalgamatedInfectionProbabilities = [1 - self.everyHostIsNotInfectedProb(infectionProbabilities[k], hostPopulations[k]) for k in range(len(hostPopulations))]
        #print("\nAmalgamated Heads Probabilities: {}".format(amalgamatedInfectionProbabilities))
        nonInfectionProbabilities = [1 - amalgamatedInfectionProbabilities[k] for k in range(len(hostPopulations))]
        #print("\nTails Probabilities: {}".format(nonInfectionProbabilities))
        typeISelectionProb = [0 for k in range(len(hostPopulations))]
        for i in range(m):
            typeJ = nonzeroHostTypes[i]
            #print(typeJ)
            probThatN_0EqualToNConditionedTypeIsJ = [0 for k in range(m)]
            for n in range(m):
                r = n
                permutations = itTools.permutations([index for index in nonzeroHostTypes if index != typeJ], r)
                #In the model's case, r = n - 1
                sum = 0
                startLoop = time.process_time()
                for permutation in permutations:
                    #print("\nPermutation = {}".format(permutation))
                    permutationTailProbs = [nonInfectionProbabilities[permutationIdx] for permutationIdx in permutation]
                    #print("Associated Tails Probabilities = {}".format(permutationTailProbs))
                    if (r == 0):
                        product = math.factorial(m - 1)
                    else:
                        product = np.prod(permutationTailProbs)
                    #This function actually returns 1 for an empty permutation list, so that actually works really well for n_0 = 1! But why does it do this?
                    #Actually, that's the problem! It actually needs to return (m-1)! (i.e. 1 for each permutation of all the back elements that aren't actually effecting when the heads shows up)
                    sum += product
                endLoop = time.process_time()
                #print("Final Sum of Permutation Products = {}".format(sum))
                #print("Time Taken: {} ms\n".format(endLoop - startLoop))
                probThatN_0EqualToNConditionedTypeIsJ[n] = (amalgamatedInfectionProbabilities[typeJ] / math.factorial(m - 1)) * sum
                #print(probThatN_0EqualToNConditionedTypeIsJ)
            
            overallProb = np.sum(probThatN_0EqualToNConditionedTypeIsJ) / m
            #print("\nProbability that the first infection occurs at type {} is {}".format(typeJ, overallProb))
            typeISelectionProb[i] = overallProb
        #print(typeISelectionProb)
        #print("Sum of the Probabilities for each type: {}".format(np.sum(typeISelectionProb)))
    
        #We need to make sure that the returned infection distribution also includes 0 for those populations which were nonexistent and excised from the algorithm
        infectionDist = [0 for k in range(len(hostPopulations))]
        numNonzeroPopulationsObserved = 0
        for k in range(len(hostPopulations)):
            if hostPopulations[k] == 0:
                infectionDist[k] = 0
            else:
                infectionDist[k] = typeISelectionProb[numNonzeroPopulationsObserved]
                numNonzeroPopulationsObserved += 1
            
        return infectionDist
    
    def fracHostsInfectedOnce(self, numHosts, numInfectingPhage):
        #[(hosts - 1)/ hosts]^phage)
        if (numHosts == 0):
            return 0
        else:
            return 1 - ((numHosts - 1) / numHosts)**numInfectingPhage
    
    def updatePhagePopulation(self, minPopIdx):
        numCorrespondingVirocells = self.phagePopulations[minPopIdx].populationLevel
        newPhageParticles = self.phagePopulations[minPopIdx].burstSize * numCorrespondingVirocells
        
        totalHostNum = sum([pop.populationLevel for pop in self.hostPopulations])

        infectionDistru = self.infectionDistribution([pop.populationLevel for pop in self.hostPopulations], minPopIdx)
        
        #print("Computed Infection Distribution: {}".format(infectionDistru))
        
        newInfections = [min([round(newPhageParticles * infectionDistru[k]), self.hostPopulations[k].populationLevel]) for k in range(len(infectionDistru))]
        
        #print("New Infections Received: {}".format(newInfections))
        self.phagePopulations[minPopIdx].populationLevel = 0

        for j in range(len(self.hostPopulations)):
            fracOfTypeJInfected = self.fracHostsInfectedOnce(self.hostPopulations[j].populationLevel, newInfections[j])
            print("Frac of Type {} Infected: {}".format(j, fracOfTypeJInfected))
            hostsOfTypeJInfected = np.ceil(self.hostPopulations[j].populationLevel * fracOfTypeJInfected)
            print("Num Hosts of Type {} Infected: {}".format(j, hostsOfTypeJInfected))
            self.hostPopulations[j].changePopulation(-hostsOfTypeJInfected)

            self.phagePopulations[minPopIdx].changePopulation(hostsOfTypeJInfected)
            #Extinction is extinction: no negative abundances.
    
    def recomputeGrowthRates(self):
        hostPopVals = [pop.populationLevel for pop in self.hostPopulations]
        for pop in self.hostPopulations:
            pop.computeGrowthRate(hostPopVals, self.carryingCapacity)

    def updateHostTimers(self, minPopTimer):
        for pop in self.hostPopulations:
            pop.updateTimer(minPopTimer)

    def updatePhageTimers(self, minPopTimer):
        for pop in self.phagePopulations:
            pop.updateTimer(minPopTimer)

    def regeneratePopTimers(self):
        for pop in self.hostPopulations:
            pop.regenerateTimer()

        for pop in self.phagePopulations:
            pop.regenerateTimer()
    
    def allPopsReportForDuty(self):
        for j in range(len(self.hostPopulations)):
            self.hostPopulations[j].reportPopInfo()

        for j in range(len(self.phagePopulations)):
            self.phagePopulations[j].reportPopInfo()

    def displayResultsAsTimecourses(self):
        if (self.completedRun == False):
            print("\nYou need to generate some data first!\n")
        else:
            for j in range(len(self.hostPopulations)):
                plt.plot(self.timeValues, self.hostPopulationValues[j, :])

# %%
mutationMatrix = np.zeros((3, 3))
mutationMatrix[0, 0] = 0.99
mutationMatrix[0, 1] = 0.01
mutationMatrix[0, 2] = 0
mutationMatrix[1, 0] = 0
mutationMatrix[1, 1] = 0.99
mutationMatrix[1, 2] = 0.01
mutationMatrix[2, 0] = 0.01
mutationMatrix[2, 1] = 0
mutationMatrix[2, 2] = 0.99

infectionMatrix = np.zeros((3, 3))
infectionMatrix[0, 0] = 1
infectionMatrix[0, 1] = 0
infectionMatrix[0, 2] = 0
infectionMatrix[1, 0] = 0
infectionMatrix[1, 1] = 1
infectionMatrix[1, 2] = 0
infectionMatrix[2, 0] = 0
infectionMatrix[2, 1] = 0
infectionMatrix[2, 2] = 1

burstSize = 2
lysisTime = 10

newInst = Instance([100, 50, 25], [20, 5, 1], 100000, [0.1, 0.1, 0.1], [burstSize, lysisTime], mutationMatrix, infectionMatrix, 5000000)

newInst.allPopsReportForDuty()

print("\nTesting findMinPopTimer()\n")
print(newInst.findMinPopTimer())

print("\nTesting updateHostPopulation()\n")
newInst.updateHostPopulation(0)

newInst.allPopsReportForDuty()

print("\nTesting runAlgorithm()\n")
newInst.runAlgorithm()

newInst.allPopsReportForDuty()

print("\nTesting displayResultsAsTimecourses()\n")
newInst.displayResultsAsTimecourses()

print(newInst.timeValues)
# Out:
# Information for Host Population 0
# -----------------------------
# Population Level: 100
# Fitness Parameter: 0.1
# Would-be Exponential Growth Rate: 10.0
# Logistic Growth Rate: 9.9825
# Timer Value: 0.08120858065176037
#
# Information for Host Population 1
# -----------------------------
# Population Level: 50
# Fitness Parameter: 0.1
# Would-be Exponential Growth Rate: 5.0
# Logistic Growth Rate: 4.99125
# Timer Value: 0.8931287186299449
#
# Information for Host Population 2
# -----------------------------
# Population Level: 25
# Fitness Parameter: 0.1
# Would-be Exponential Growth Rate: 2.5
# Logistic Growth Rate: 2.495625
# Timer Value: 0.10189495077859707
#
# Information for Phage Population 0
# -----------------------------
# Population Level: 20
# Burst Size: 2
# Lysis Time: 10
# Timer Value: 10.117
#
# Information for Phage Population 1
# -----------------------------
# Population Level: 5
# Burst Size: 2
# Lysis Time: 10
# Timer Value: 9.628
#
# Information for Phage Population 2
# -----------------------------
# Population Level: 1
# Burst Size: 2
# Lysis Time: 10
# Timer Value: 9.673
#
# Testing findMinPopTimer()
#
# (False, 0.01, False, 0)
#
# Testing updateHostPopulation()
#
#
# Information for Host Population 0
# -----------------------------
# Population Level: 101
# Fitness Parameter: 0.1
# Would-be Exponential Growth Rate: 10.100000000000001
# Logistic Growth Rate: 9.9825
# Timer Value: 0.08120858065176037
#
# Information for Host Population 1
# -----------------------------
# Population Level: 50
# Fitness Parameter: 0.1
# Would-be Exponential Growth Rate: 5.0
# Logistic Growth Rate: 4.99125
# Timer Value: 0.8931287186299449
#
# Information for Host Population 2
# -----------------------------
# Population Level: 25
# Fitness Parameter: 0.1
# Would-be Exponential Growth Rate: 2.5
# Logistic Growth Rate: 2.495625
# Timer Value: 0.10189495077859707
#
# Information for Phage Population 0
# -----------------------------
# Population Level: 20
# Burst Size: 2
# Lysis Time: 10
# Timer Value: 10.117
#
# Information for Phage Population 1
# -----------------------------
# Population Level: 5
# Burst Size: 2
# Lysis Time: 10
# Timer Value: 9.628
#
# Information for Phage Population 2
# -----------------------------
# Population Level: 1
# Burst Size: 2
# Lysis Time: 10
# Timer Value: 9.673
#
# Testing runAlgorithm()
#
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.5861297539149888, 0.28859060402684567, 0.12527964205816555]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.07487036414634407
# Num Hosts of Type 1 Infected: 10.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.5990888382687927, 0.2733485193621868, 0.1275626423690205]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.03539540816326536
# Num Hosts of Type 2 Infected: 2.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.6048034934497817, 0.27729257641921395, 0.11790393013100436]
# Frac of Type 0 Infected: 0.13468841133858556
# Num Hosts of Type 0 Infected: 38.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.5578300921187308, 0.3295803480040942, 0.11258955987717502]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.035870767024110184
# Num Hosts of Type 2 Infected: 4.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.5577492596248766, 0.3336623889437315, 0.10858835143139191]
# Frac of Type 0 Infected: 0.12596289786918835
# Num Hosts of Type 0 Infected: 72.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.5227722772277228, 0.3603960396039604, 0.11683168316831684]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0535344132672968
# Num Hosts of Type 1 Infected: 20.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.5351530190239868, 0.34863523573200994, 0.11621174524400331]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.0281176581383471
# Num Hosts of Type 2 Infected: 8.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.5390070921985816, 0.3486997635933806, 0.11229314420803782]
# Frac of Type 0 Infected: 0.09994701937619443
# Num Hosts of Type 0 Infected: 137.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.5171407731582787, 0.3665207877461707, 0.1163384390955507]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.03903838123546699
# Num Hosts of Type 1 Infected: 40.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.5148840429214261, 0.36690896503980613, 0.11820699203876774]
# Frac of Type 0 Infected: 0.08800094303556394
# Num Hosts of Type 0 Infected: 262.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.4936515997968512, 0.38378195361435585, 0.12256644658879295]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.02187198578345284
# Num Hosts of Type 2 Infected: 16.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.4905442471488379, 0.38819113613396855, 0.12126461671719359]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.029318008067166446
# Num Hosts of Type 1 Infected: 79.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.48540981261622085, 0.38599628093262767, 0.12859390645115149]
# Frac of Type 0 Infected: 0.07430651830514445
# Num Hosts of Type 0 Infected: 505.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.46602012014185423, 0.3998697257002244, 0.1341101541579214]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.01712561514693567
# Num Hosts of Type 2 Infected: 32.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.46644357687302473, 0.3997645163289335, 0.13379190679804176]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.02419667612925025
# Num Hosts of Type 1 Infected: 157.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.4698158526821457, 0.3932425940752602, 0.13694155324259408]
# Frac of Type 0 Infected: 0.06653362383752404
# Num Hosts of Type 0 Infected: 977.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.4527511374423096, 0.4061732840168898, 0.14107557854080063]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.014741179941559546
# Num Hosts of Type 2 Infected: 64.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.45478382472905254, 0.40633376063395876, 0.1388824146369887]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.02226304707089566
# Num Hosts of Type 1 Infected: 311.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.4599282296650718, 0.39907296650717705, 0.1409988038277512]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.016825100880283772
# Num Hosts of Type 2 Infected: 127.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0

# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.6322668232706168
# Num Hosts of Type 1 Infected: 796.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.19392867668729738, 0.2796934865900383, 0.5263778367226644]
# Frac of Type 0 Infected: 0.6324002796274879
# Num Hosts of Type 0 Infected: 417.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.08439067571555031, 0.3139569194452641, 0.6016524048391856]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.6322107880181286
# Num Hosts of Type 2 Infected: 1290.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.13556618819776714, 0.5099681020733652, 0.35446570972886765]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.6322644209607482
# Num Hosts of Type 1 Infected: 809.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.18653901943719176, 0.28372497824194953, 0.5297360023208587]
# Frac of Type 0 Infected: 0.6324068092283266
# Num Hosts of Type 0 Infected: 407.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.07836181876813932, 0.3227990970654628, 0.598839084166398]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.6322196331437884
# Num Hosts of Type 2 Infected: 1175.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.1276595744680851, 0.5176015473887814, 0.3547388781431335]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.6322580752879794
# Num Hosts of Type 1 Infected: 846.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.1782092147203709, 0.2854245146334396, 0.5363662706461895]
# Frac of Type 0 Infected: 0.6324198506048141
# Num Hosts of Type 0 Infected: 389.0
# Frac of Type 1 Infected: 0.0
# ...
#
# Extant Host Types: [1 2]
#
# Pop Fracs = [0.7692307692307693, 0.23076923076923078]
# Frac of Type 0 Infected: 0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.6447356335058557
# Num Hosts of Type 2 Infected: 10.0
#
# Extant Host Types: [1 2]
#
# Pop Fracs = [0.9090909090909091, 0.09090909090909091]
# Frac of Type 0 Infected: 0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [1 2]
#
# Pop Fracs = [0.8829787234042553, 0.11702127659574468]
# Frac of Type 0 Infected: 0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.6343478927235231
# Num Hosts of Type 1 Infected: 53.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [1 2]
#
# Pop Fracs = [0.7205882352941176, 0.27941176470588236]
# Frac of Type 0 Infected: 0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.6420196577965368
# Num Hosts of Type 2 Infected: 13.0
#
# Extant Host Types: [1 2]
#
# Pop Fracs = [0.875, 0.125]
# Frac of Type 0 Infected: 0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.635059701607434
# Num Hosts of Type 1 Infected: 41.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [1 2]
#
# Pop Fracs = [0.6739130434782609, 0.32608695652173914]
# Frac of Type 0 Infected: 0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.6447356335058557
# Num Hosts of Type 2 Infected: 10.0
#
# Extant Host Types: [1 2]
#
# Pop Fracs = [0.8245614035087719, 0.17543859649122806]
# Frac of Type 0 Infected: 0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.6360692386045428
# Num Hosts of Type 1 Infected: 30.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [1 2]
#
# Pop Fracs = [0.6111111111111112, 0.3888888888888889]
# Frac of Type 0 Infected: 0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.6231105171269997
# Num Hosts of Type 2 Infected: 14.0
#
# Extant Host Types: [1 2]
#
# Pop Fracs = [0.8533333333333334, 0.14666666666666667]
# Frac of Type 0 Infected: 0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.6112821104343957
# Num Hosts of Type 1 Infected: 40.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [1 2]
#
# Pop Fracs = [0.7142857142857143, 0.2857142857142857]
# Frac of Type 0 Infected: 0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.6415140775914581
# Num Hosts of Type 2 Infected: 13.0
#
# Extant Host Types: [1 2]
#
# Pop Fracs = [0.8723404255319149, 0.1276595744680851]
# Frac of Type 0 Infected: 0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.6252916943686959
# Num Hosts of Type 1 Infected: 52.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [1 2]
#
# Pop Fracs = [0.6805555555555556, 0.3194444444444444]
# Frac of Type 0 Infected: 0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0

# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.6323266345211542
# Num Hosts of Type 1 Infected: 565.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.9955031627372053, 0.004439332949971248, 5.750431282346176e-05]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.6723199999999999
# Num Hosts of Type 2 Infected: 4.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.994965699778534, 0.005023497002106627, 1.0803219359369092e-05]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.6325164829545104
# Num Hosts of Type 1 Infected: 295.0
# Frac of Type 2 Infected: 0.0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1 2]
#
# Pop Fracs = [0.9978269583746493, 0.002151944133842486, 2.1097491508259668e-05]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0.75
# Num Hosts of Type 2 Infected: 2.0
#
# Extant Host Types: [0 1]
#
# Pop Fracs = [0.9976126005084851, 0.0023873994915149135]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.6329182740756596
# Num Hosts of Type 1 Infected: 147.0
# Frac of Type 2 Infected: 0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1]
#
# Pop Fracs = [0.9989592473930168, 0.0010407526069832458]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1]
#
# Pop Fracs = [0.9988666491267126, 0.0011333508732873246]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.6337690149933252
# Num Hosts of Type 1 Infected: 71.0
# Frac of Type 2 Infected: 0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1]
#
# Pop Fracs = [0.9995176558072231, 0.00048234419277689574]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.6359862515151655
# Num Hosts of Type 1 Infected: 31.0
# Frac of Type 2 Infected: 0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1]
#
# Pop Fracs = [0.9997795370277583, 0.0002204629722417076]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.6406434989043935
# Num Hosts of Type 1 Infected: 15.0
# Frac of Type 2 Infected: 0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1]
#
# Pop Fracs = [0.9998898987068102, 0.00011010129318973456]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.6495061005186076
# Num Hosts of Type 1 Infected: 8.0
# Frac of Type 2 Infected: 0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0 1]
#
# Pop Fracs = [0.9999699870944506, 3.0012905549386236e-05]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0.7037037037037037
# Num Hosts of Type 1 Infected: 3.0
# Frac of Type 2 Infected: 0
# Num Hosts of Type 2 Infected: 0.0
#
# Extant Host Types: [0]
#
# Pop Fracs = [1.0]
# Frac of Type 0 Infected: 0.0
# Num Hosts of Type 0 Infected: 0.0
# Frac of Type 1 Infected: 0
# Num Hosts of Type 1 Infected: 0.0
# Frac of Type 2 Infected: 0
# Num Hosts of Type 2 Infected: 0.0
#
# Information for Host Population 0
# -----------------------------
# Population Level: 99999.0
# Fitness Parameter: 0.1
# Would-be Exponential Growth Rate: 9999.900000000001
# Logistic Growth Rate: 0.0
# Timer Value: inf
#
# Information for Host Population 1
# -----------------------------
# Population Level: 1.0
# Fitness Parameter: 0.1
# Would-be Exponential Growth Rate: 0.1
# Logistic Growth Rate: 0.0
# Timer Value: inf
#
# Information for Host Population 2
# -----------------------------
# Population Level: 0.0
# Fitness Parameter: 0.1
# Would-be Exponential Growth Rate: 0.0
# Logistic Growth Rate: 0.0
# Timer Value: inf
#
# Information for Phage Population 0
# -----------------------------
# Population Level: 0.0
# Burst Size: 2
# Lysis Time: 10
# Timer Value: inf
#
# Information for Phage Population 1
# -----------------------------
# Population Level: 0.0
# Burst Size: 2
# Lysis Time: 10
# Timer Value: inf
#
# Information for Phage Population 2
# -----------------------------
# Population Level: 0.0
# Burst Size: 2
# Lysis Time: 10
# Timer Value: inf
#
# Testing displayResultsAsTimecourses()
#
# [0.00000000e+00 1.00000000e-02 2.00000000e-02 ... 3.23095049e+04
#  3.23095149e+04 3.23095249e+04]
